# %% [markdown]
# # Test Notebook for Binder
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/andymcdgeo/binder_test/main)

# %%
import lasio as las
import matplotlib.pyplot as plt

# %%
data = las.read('15-9-19_SR_COMP.LAS')

# %%
df = data.df()

# %%
df.head()
# Out:
#           AC  CALI  DEN      GR  NEU  RDEP  RMED
# DEPT
# 102.1568 NaN   NaN  NaN  5.3274  NaN   NaN   NaN
# 102.3092 NaN   NaN  NaN  5.8235  NaN   NaN   NaN
# 102.4616 NaN   NaN  NaN  6.5228  NaN   NaN   NaN
# 102.6140 NaN   NaN  NaN  7.2285  NaN   NaN   NaN
# 102.7664 NaN   NaN  NaN  9.5020  NaN   NaN   NaN

# %%
df.plot('NEU', 'DEN', kind='scatter', c='GR', cmap='hot')
plt.xlim(0, 60)
plt.ylim(3, 1.5)
plt.show()

# %%
df['DEPTH']=df.index

# %%
df.plot('DEPTH', 'GR', c='green')
